# %%
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline
x = np.linspace(0, 3, num = 100)
y = -x**2 + 3*x -1
plt.plot(x,y)

# %%
import seaborn
seaborn.set(style='darkgrid')

def draw_secant(x_values):
    x = np.linspace(-20,30,100)
    y = -1*(x**2) + x*3 - 1
    plt.plot(x,y)
    x_0 = x_values[0]
    x_1 = x_values[1]
    y_0 = -1*(x_0**2) + x_0*3 - 1
    y_1 = -1*(x_1**2) + x_1*3 - 1
    m = (y_1 - y_0) / (x_1 - x_0)
    b = y_1 - m*x_1
    
    y_secant = x*m + b
    plt.plot(x, y_secant, c='green')
    plt.show()
draw_secant([3,5])
draw_secant([3,10])
draw_secant([3,15])

# %% [markdown]
# #### finding limits

# %%
import sympy
x,y = sympy.symbols('x y')
y = x^2 +1
print(y)
# Out:
# ~x

# %%
import sympy
x2,y = sympy.symbols('x2 y')
limit_one = sympy.limit((-x2**2+3*x2-1-(-1))/(x2-3), x2, 2.9)
print(limit_one)
# Out:
# -2.89999999999999

# %%
y = 3*(x**2)+3*x-3
limit_two = sympy.limit(y, x, 1)
print(limit_two)
# Out:
# 3

# %%
y = x**3 + 2*(x**2) - 10*x
limit_three = sympy.limit(y, x, -1)
print(limit_three)
# Out:
# 11

# %% [markdown]
# #### finding extreme points (min ans max)

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(-5,6,110)
y = -2*x+3
plt.plot(x,y)

# %%
y = x**3+x**2
plt.plot(x,y)

# %% [markdown]
# #### linear systems

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.linspace(0,50,1000)
y1=30*x+1000
y2=50*x+100
plt.plot(x,y1, color='orange')
plt.plot(x,y2, color='blue')

# %% [markdown]
# ```
# general form: AX +BY = c
# 30x - y = 1000
# 50x -y = 100
# augmented matrix: [30, -1, | -1000]
#                   [50, -1, | -100] ```

# %%
# representing an augmented matrix:
matrix_one = np.asarray([
    [30, -1, -1000],
    [50, -1, -100]])

# %%
matrix_one = np.asarray([
    [30, -1, -1000],
    [50, -1, -100]  
], dtype=np.float32)

# %%
matrix =  np.asarray([
    [1, 3],
    [50, 2]  
], dtype=np.float32)
# Swap the second row (at index value 1) with the first row (at index value 0).
matrix = matrix[[1,0]]
print(matrix)
print(matrix[1])
# Out:
# [[50.  2.]
#  [ 1.  3.]]
# [1. 3.]

# %%
matrix_one = np.asarray([
    [30, -1, -500],
    [50, -1, -100]  
], dtype=np.float32)
matrix_one[0] = matrix_one[0]/30
print(matrix_one[0])
# Out:
# [  1.          -0.03333334 -16.666666  ]

# %%
matrix_three = np.asarray([
    [1, -1/30, -1000/30],
    [0, 1, 2350]  
], dtype=np.float32)
matrix_three[0] += matrix_three[1]/30
print(matrix_three)
# Out:
# [[1.0000000e+00 0.0000000e+00 4.5000004e+01]
#  [0.0000000e+00 1.0000000e+00 2.3500000e+03]]

# %%
# visualize vectors in matplotlib using the pyplot.quiver()function
import matplotlib.pyplot as plt
import numpy as np

# This code draws the x and y axis as lines.
plt.axhline(0, c='black', lw=0.5)
plt.axvline(0, c='black', lw=0.5)
plt.xlim(-3,3)
plt.ylim(-4,4)

plt.quiver(0, 0, 2, 3, angles='xy', scale_units='xy', scale=1, color='blue')
plt.quiver(0, 0, -2, -3, angles='xy', scale_units='xy', scale=1, color='blue')
plt.quiver(0, 0, 1, 1, angles='xy', scale_units='xy', scale=1, color='gold')
plt.quiver(0, 0, 2, 2, angles='xy', scale_units='xy', scale=1, color='gold')

# %%
plt.axhline(0, c='black', lw=0.5)
plt.axvline(0, c='black', lw=0.5)
plt.xlim(-4,4)
plt.ylim(-1,4)

# Add your code here.
plt.quiver(0, 0, 3, 0, angles='xy', scale_units='xy', scale=1)
plt.quiver(3, 0, 0, 3, angles='xy', scale_units='xy', scale=1)
plt.quiver(0, 0, 3, 3, angles='xy', scale_units='xy', scale=1, color='green')

# %%
plt.axhline(0, c='black', lw=0.5)
plt.axvline(0, c='black', lw=0.5)
plt.xlim(0,10)
plt.ylim(0,5)
plt.quiver(0, 0, 3, 1, angles='xy', scale_units='xy', scale=1, color='blue')
plt.quiver(0, 0, 6, 2, angles='xy', scale_units='xy', scale=1, color='green')
plt.quiver(0, 0, 9, 3, angles='xy', scale_units='xy', scale=1, color='orange')

# %%
print(matrix_three[1])
# Out:
# [0.00e+00 1.00e+00 2.35e+03]

# %% [markdown]
# #### vector opertions

# %%
`vector_one = np.asarray([
    [1],
    [2],
    [1]
], dtype=np.float32)
vector_two = np.asarray([
    [3],
    [0],
    [1]])
vector_linear_combination = vector_one *2 + vector_two*5
print(vector_linear_combination)
# Out:
# [[17.]
#  [ 4.]
#  [ 7.]]

# %%
vector_one = np.asarray([
    [1],
    [2],
    [1]
], dtype=np.float32)

vector_two = np.asarray([
    [3],
    [0],
    [1]
], dtype=np.float32)

dot_product = np.dot(vector_one[:,0], vector_two)
print(dot_product)
# Out:
# [4.]

# %%
v = np.asarray([
    [3],
    [1]
], dtype=np.float32)

w = np.asarray([
    [1],
    [2]
], dtype=np.float32)

end_point = 2*v - 2*w
print(end_point)
# Out:
# [[ 4.]
#  [-2.]]

# %%
matrix_a = np.asarray([
    [0.7,3,9],
    [1.7,2,9],
    [0.7,9,2]])
vector_b = np.asarray([[1],[2],[1]])
ab_product = np.dot(matrix_a, vector_b)
print(ab_product)
# Out:
# [[15.7]
#  [14.7]
#  [20.7]]

# %%
matrix_a = np.asarray([
    [0.7, 3],
    [1.7, 2],
    [0.7, 9]
], dtype=np.float32)

matrix_b = np.asarray([
    [113, 3, 10],
    [1, 0, 1],
], dtype=np.float32)
product_ab = np.dot(matrix_a, matrix_b)
product_ba = np.dot(matrix_b, matrix_a)
print(product_ab)
print('\n', product_ba)
# Out:
# [[ 82.1         2.1        10.       ]
#  [194.1         5.1000004  19.       ]
#  [ 88.1         2.1        16.       ]]
#
#  [[ 91.2 435. ]
#  [  1.4  12. ]]

# %% [markdown]
# #### matrix transpose

# %%
matrix_a = np.asarray([
    [0.7, 3],
    [1.7, 2],
    [0.7, 9]
], dtype=np.float32)

matrix_b = np.asarray([
    [113, 3, 10],
    [1, 0, 1],
], dtype=np.float32)

transpose_a = np.transpose(matrix_a)
print('A^T\n', transpose_a)
matrix_a = np.transpose(transpose_a)
print('\n(A^T)^T\n', matrix_a)

trans_ba = np.dot(np.transpose(matrix_b), transpose_a)    # B^T * A^T
trans_ab = np.dot(transpose_a, np.transpose(matrix_b))    # A^T * B^T
print('\nB^T * A^T\n', trans_ba)

product_ab = np.dot(matrix_a, matrix_b)                   # (AB)^T
print('\n(AB)^T\n', np.transpose(product_ab))
# Out:
# A^T
#  [[0.7 1.7 0.7]
#  [3.  2.  9. ]]
#
# (A^T)^T
#  [[0.7 3. ]
#  [1.7 2. ]
#  [0.7 9. ]]
#
# B^T * A^T
#  [[ 82.1       194.1        88.1      ]
#  [  2.1         5.1000004   2.1      ]
#  [ 10.         19.         16.       ]]
#
# (AB)^T
#  [[ 82.1       194.1        88.1      ]
#  [  2.1         5.1000004   2.1      ]
#  [ 10.         19.         16.       ]]

# %% [markdown]
# #### identity matrix

# %%
# generating identity matrix using np.identity()
i_2 = np.identity(2)
i_3 = np.identity(3)
matrix_33 = np.asarray([
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
])

matrix_23 = np.asarray([
    [0.7, 3, 1],
    [1.7, 2, 10],
], dtype=np.float32)

identity_33 = np.dot(i_3, matrix_33)
identity_23 = np.dot(i_2, matrix_23)

print(identity_33)
print('\n', identity_23)
# Out:
# [[1. 2. 3.]
#  [4. 5. 6.]
#  [7. 8. 9.]]
#
#  [[ 0.69999999  3.          1.        ]
#  [ 1.70000005  2.         10.        ]]

# %% [markdown]
# ````
# inverse matrix
# A = [a b      A^(-1) = 1/(ad-bc)[d -b]
#      c d]                        -c a]```

# %%
matrix_a = np.asarray([
    [1.5, 3],
    [1, 4]
])
def matrix_inverse_two(mat):
    det = (mat[0,0]*mat[1,1] - mat[0,1]*mat[1,0])  # determinant
    if det == 0:
        raise ValueError("The matrix isn't invertible")
    right_mat = np.asarray([
        [mat[1,1], -mat[0,1]],
        [-mat[1,0], mat[0,0]]
    ])
    inv_mat = np.dot(1/det, right_mat)
    return inv_mat
inverse_a = matrix_inverse_two(matrix_a)
i_2 = np.dot(inverse_a, matrix_a)
print(i_2)
# Out:
# [[1. 0.]
#  [0. 1.]]

# %%
a= np.asarray([
    [30, -1],
    [50, -1]])
b = np.asarray([
    [-1000], [-100]])
a_inv = np.linalg.inv(a)  # Compute the inverse of a matrix
solution_x = np.dot(a_inv, b)
print(solution_x)
# Out:
# [[  45.]
#  [2350.]]

# %%
# The determinant of a higher-dimensional system involves breaking down the full matrix into minor matrices
# Use numpy.linalg.det() to compute the determinant 
matrix_22 = np.asarray([
    [8, 4],
    [4, 2]
])

matrix_33 = np.asarray([
    [1, 1, 1],
    [1, 1, 6],
    [7, 8, 9]
])
det_22 = np.linalg.det(matrix_22)
det_33 = np.linalg.det(matrix_33)
print(det_22, '  ', det_33)
# Out:
# 0.0    -4.999999999999997

# %% [markdown]
# #### inconsistent systems

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0,20,1000)
y1 = -2*x+5/4
y2 = -2*x+2.5
plt.plot(x, y1, color='blue')
plt.plot(x, y2, color='blue')

# %% [markdown]
# #### linear regression model

# %%
import pandas as pd
data = pd.read_table('C:/Users/\Xueho\Projects\Machine_learning_projects/Raw_data/AmesHousing.txt', sep='\t')
train = data.iloc[0:1460, :]
test = data.iloc[1460:, :]
data.info()
data.columns
target='SalePrice'
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 82 columns):
# Order              2930 non-null int64
# PID                2930 non-null int64
# MS SubClass        2930 non-null int64
# MS Zoning          2930 non-null object
# Lot Frontage       2440 non-null float64
# Lot Area           2930 non-null int64
# Street             2930 non-null object
# Alley              198 non-null object
# Lot Shape          2930 non-null object
# Land Contour       2930 non-null object
# Utilities          2930 non-null object
# Lot Config         2930 non-null object
# Land Slope         2930 non-null object
# Neighborhood       2930 non-null object
# Condition 1        2930 non-null object
# Condition 2        2930 non-null object
# Bldg Type          2930 non-null object
# House Style        2930 non-null object
# Overall Qual       2930 non-null int64
# Overall Cond       2930 non-null int64
# Year Built         2930 non-null int64
# ...

# %%
import matplotlib.pyplot as plt
import seaborn
fig = plt.figure(figsize=(16,3))
ax1 = fig.add_subplot(1, 3, 1)
ax2 = fig.add_subplot(1, 3, 2)
ax3 = fig.add_subplot(1, 3, 3)

train.plot(x="Garage Area", y="SalePrice", ax=ax1, kind="scatter")
train.plot(x="Gr Liv Area", y="SalePrice", ax=ax2, kind="scatter")
train.plot(x="Overall Cond", y="SalePrice", ax=ax3, kind="scatter")

# %%
print(train[['Garage Area', 'Gr Liv Area', 'Overall Cond', 'SalePrice']].corr())

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(train[['Gr Liv Area']], train['SalePrice'])
print(lr.coef_)
print(lr.intercept_)

a0 = lr.intercept_
a1 = lr.coef_
# Out:
# [116.86624683]
# 5366.821710056043

# %%
import numpy as np
from sklearn.metrics import mean_squared_error

train_predictions = lr.predict(train[['Gr Liv Area']])
test_predictions = lr.predict(test[['Gr Liv Area']])

train_mse = mean_squared_error(train_predictions, train['SalePrice'])
test_mse = mean_squared_error(test_predictions, test['SalePrice'])

train_rmse = np.sqrt(train_mse)
test_rmse = np.sqrt(test_mse)

print(train_rmse)
print(test_rmse)
# Out:
# 56034.362001412796
# 57088.25161263909

# %%
cols = ['Overall Cond', 'Gr Liv Area']
lr = LinearRegression()
lr.fit(train[cols], train['SalePrice'])
from sklearn.metrics import mean_squared_error

train_predictions = lr.predict(train[cols])
test_predictions = lr.predict(test[cols])

train_mse = mean_squared_error(train_predictions, train['SalePrice'])
test_mse = mean_squared_error(test_predictions, test['SalePrice'])

train_rmse_2 = np.sqrt(train_mse)
test_rmse_2 = np.sqrt(test_mse)

print(train_rmse_2)
print(test_rmse_2)
# Out:
# 56032.398015258674
# 57066.90779448559

# %% [markdown]
# #### feature selection

# %%
import pandas as pd
data = pd.read_table('C:/Users/\Xueho\Projects\Machine_learning_projects/Raw_data/AmesHousing.txt', sep='\t')
train = data[0:1460]
test = data[1460:]
numerical_train = train.select_dtypes(exclude=['object'])
numerical_train = numerical_train.drop(['PID', 'Year Built', 'Year Remod/Add', 'Garage Yr Blt', 'Mo Sold', 'Yr Sold'], axis=1)
# Calculate the number of missing values from each column in numerical_train
null_series = numerical_train.isnull().sum()
full_cols_series = null_series[null_series == 0]
print(full_cols_series)
# Out:
# Order              0
# MS SubClass        0
# Lot Area           0
# Overall Qual       0
# Overall Cond       0
# 1st Flr SF         0
# 2nd Flr SF         0
# Low Qual Fin SF    0
# Gr Liv Area        0
# Full Bath          0
# Half Bath          0
# Bedroom AbvGr      0
# Kitchen AbvGr      0
# TotRms AbvGrd      0
# Fireplaces         0
# Garage Cars        0
# Garage Area        0
# Wood Deck SF       0
# Open Porch SF      0
# Enclosed Porch     0
# 3Ssn Porch         0
# Screen Porch       0
# Pool Area          0
# Misc Val           0
# SalePrice          0
# dtype: int64

# %%
len(full_cols_series)
# Out:
# 25

# %%
train_subset = train[full_cols_series.index]
cor = train_subset.corr()
sorted_corrs = cor['SalePrice'].abs().sort_values()
print(sorted_corrs)
# Out:
# Misc Val           0.009903
# 3Ssn Porch         0.038699
# Low Qual Fin SF    0.060352
# Order              0.068181
# MS SubClass        0.088504
# Overall Cond       0.099395
# Screen Porch       0.100121
# Bedroom AbvGr      0.106941
# Kitchen AbvGr      0.130843
# Pool Area          0.145474
# Enclosed Porch     0.165873
# 2nd Flr SF         0.202352
# Half Bath          0.272870
# Lot Area           0.274730
# Wood Deck SF       0.319104
# Open Porch SF      0.344383
# TotRms AbvGrd      0.483701
# Fireplaces         0.485683
# Full Bath          0.518194
# 1st Flr SF         0.657119
# Garage Area        0.662397
# Garage Cars        0.663485
# Gr Liv Area        0.698990
# Overall Qual       0.804562
# SalePrice          1.000000
# Name: SalePrice, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
strong_corrs = sorted_corrs[sorted_corrs > 0.3]
corrmat = train_subset[strong_corrs.index].corr()
sns.heatmap(corrmat, cmap="YlGnBu")

# %%
# Gr Liv Area and Garage Area, TotRms AbvGrd and Garage Cars contains similar info. drop latter ones.
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np

final_corr_cols = strong_corrs.drop(['Garage Cars', 'TotRms AbvGrd'])
features = final_corr_cols.drop(['SalePrice']).index
target = 'SalePrice'
clean_test = test[final_corr_cols.index].dropna()

lr = LinearRegression()
lr.fit(train[features], train['SalePrice'])

train_predictions = lr.predict(train[features])
test_predictions = lr.predict(clean_test[features])

train_mse = mean_squared_error(train_predictions, train[target])
test_mse = mean_squared_error(test_predictions, clean_test[target])

train_rmse = np.sqrt(train_mse)
test_rmse = np.sqrt(test_mse)

print(train_rmse)
print(test_rmse)
# Out:
# 34173.97629185852
# 356853098.33880657

# %%
# removing features with low variance
train[features] = (train[features]-train[features].min())/(train[features].max()-train[features].min())
sorted_vars = train[features].var().sort_values()
print('\n', sorted_vars)
# Out:
#  Open Porch SF    0.013938
# Full Bath        0.018621
# Garage Area      0.020347
# Gr Liv Area      0.023078
# Overall Qual     0.024496
# 1st Flr SF       0.025814
# Wood Deck SF     0.033064
# Fireplaces       0.046589
# dtype: float64
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
#set a cutoff variance of 0.015, remove the Open Porch SF feature
features = features.drop('Open Porch SF')
lr.fit(train[features], train['SalePrice'])
train_predictions = lr.predict(train[features])
test_prediction = lr.predict(clean_test[features])
mse_train = mean_squared_error(train_predictions, train['SalePrice'])
mse_target = mean_squared_error(test_prediction, clean_test[target])
train_rmse_2 = np.sqrt(mse_train)
test_rmse_2 = np.sqrt(mse_target)
print(train_rmse_2, ' ', test_rmse_2)
# Out:
# 34372.696707783965   363293753.52097446

# %% [markdown]
# #### gradient descent
# ```single parameter gradient descent
#    cost function / the loss function
#    MSE(a1) = 1/n[SUM(a1*x(i) - y(i))^2
#    dMSE(a1)/da1 = (2/n)SUM[x(i) * (a1*x(i) -y(i))]
#    a1 := a1 - Alpha* dMSE(a1)/da1   alpha=learning rate```

# %%
def derivative(a1, xi_list, yi_list):
    len_data = len(xi_list)
    error = 0
    for i in range(0, len_data):
        error += xi_list[i]*(a1*xi_list[i] - yi_list[i])
    deriv = 2*error/len_data
    return deriv

def gradient_descent(xi_list, yi_list, max_iterations, alpha, a1_initial):
    a1_list = [a1_initial]

    for i in range(0, max_iterations):
        a1 = a1_list[i]
        deriv = derivative(a1, xi_list, yi_list)
        a1_new = a1 - alpha*deriv
        a1_list.append(a1_new)
    return(a1_list)

param_iterations = gradient_descent(train['Gr Liv Area'], train['SalePrice'], 20, .0000003, 150)
final_param = param_iterations[-1]
print(final_param)
# Out:
# 150.85658179616752

# %% [markdown]
# ```multi parameter gradient descent
#    cost function / the loss function
#    MSE(a0, a1) = (1/2n)[SUM(a0 + a1*x(i) - y(i))^2
#    dMSE/da0 = (1/n)SUM[(a0 + a1*x(i) -y(i))]
#    dMSE/da1 = (1/n)SUM[x1(i) * (a0 + a1*x(i) -y(i))]
#    dMSE/dan = (1/n)SUM[xn(i) * (a0 + an*x(i) -y(i))]
#
#    a1 := a1 - Alpha* dMSE(a0,a1)/da1   alpha=learning rate
#    a0 := a0 - Alpha* dMSE(a0,a1)/da0   alpha=learning rate
# ```

# %%
def a1_derivative(a0, a1, xi_list, yi_list):
    len_data = len(xi_list)
    error = 0
    for i in range(0, len_data):
        error += xi_list[i]*(a0 + a1*xi_list[i] - yi_list[i])
    deriv = error/len_data
    return deriv

def a0_derivative(a0, a1, xi_list, yi_list):
    len_data = len(xi_list)
    error = 0
    for i in range(0, len_data):
        error += a0 + a1*xi_list[i] - yi_list[i]
    deriv = error/len_data
    return deriv

def gradient_descent(xi_list, yi_list, max_iterations, alpha, a1_initial, a0_initial):
    a1_list = [a1_initial]
    a0_list = [a0_initial]

    for i in range(0, max_iterations):
        a1 = a1_list[i]
        a0 = a0_list[i]
        a1_deriv = a1_derivative(a0, a1, xi_list, yi_list)
        a0_deriv = a0_derivative(a0, a1, xi_list, yi_list)
        a1_new = a1 - alpha*a1_deriv
        a0_new = a0 - alpha*a0_deriv
        a1_list.append(a1_new)
        a0_list.append(a0_new)
    return(a0_list, a1_list)

a0_params, a1_params = gradient_descent(train['Gr Liv Area'], train['SalePrice'], 20, .0000003, 150, 1000)
print(a0_params[-1], '  ', a1_params[-1])
# Out:
# 1001.0713264309778    150.42618253448686

# %% [markdown]
# #### ordinary least squares

# %% [markdown]
# ``` OLS estimation provides a closed form solution to the problem of finding the optimal parameter values.
#     A closed form solution is one where a solution can be computed arithmetically with a predictable amount of mathematical operations.
#  Cost Function: J(a) = (1/n) (X*a-y)^T * (X*a-y)
#  dJ(a)/da = 2(X^T)Xa -2(X^T)y
#  solving a = ((X^T)X)^(-1)*(X^T)*y
#  computing a matrix inverse has a computational complexity of apprximately O(n^3) ```

# %% [markdown]
# #### processing and transforming features

# %%
#  feature engineering: the process of processing and creating new features

import pandas as pd
data = pd.read_table('C:/Users/\Xueho\Projects\Machine_learning_projects/Raw_data/AmesHousing.txt', sep='\t')
train = data[0:1460]
test = data[1460:]
train_null_counts = train.isnull().sum()
df_no_mv = train[train_null_counts[train_null_counts==0].index]
df_no_mv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 58 columns):
# Order              1460 non-null int64
# PID                1460 non-null int64
# MS SubClass        1460 non-null int64
# MS Zoning          1460 non-null object
# Lot Area           1460 non-null int64
# Street             1460 non-null object
# Lot Shape          1460 non-null object
# Land Contour       1460 non-null object
# Utilities          1460 non-null object
# Lot Config         1460 non-null object
# Land Slope         1460 non-null object
# Neighborhood       1460 non-null object
# Condition 1        1460 non-null object
# Condition 2        1460 non-null object
# Bldg Type          1460 non-null object
# House Style        1460 non-null object
# Overall Qual       1460 non-null int64
# Overall Cond       1460 non-null int64
# Year Built         1460 non-null int64
# Year Remod/Add     1460 non-null int64
# Roof Style         1460 non-null object
# ...

# %%
text_cols = df_no_mv.select_dtypes(include=['object']).columns
for col in text_cols:
    print(col+":", len(train[col].unique()))
    train[col] = train[col].astype('category')
train['Utilities'].cat.codes.value_counts()
# Converting columns in text_cols from the train data frame into dummy column
for col in text_cols:
    col_dummies = pd.get_dummies(train[col])
    train = pd.concat([train, col_dummies], axis=1)
    del train[col]
# Out:
# MS Zoning: 6
# Street: 2
# Lot Shape: 4
# Land Contour: 4
# Utilities: 3
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# Lot Config: 5
# Land Slope: 3
# Neighborhood: 26
# Condition 1: 9
# Condition 2: 6
# Bldg Type: 5
# House Style: 8
# Roof Style: 6
# Roof Matl: 5
# Exterior 1st: 14
# Exterior 2nd: 16
# Exter Qual: 4
# Exter Cond: 5
# Foundation: 6
# Heating: 6
# Heating QC: 4
# Central Air: 2
# Electrical: 4
# Kitchen Qual: 5
# Functional: 7
# Paved Drive: 3
# Sale Type: 9
# Sale Condition: 5

# %%
# transform numerical columns that are categorical with a limited set of unique values
train['years_until_remod'] = train['Year Remod/Add'] - train['Year Built']
df_missing_values = train[train_null_counts[(train_null_counts>0) & (train_null_counts<584)].index]
print(df_missing_values.isnull().sum())
print('\n', df_missing_values.dtypes)
# Out:
# Lot Frontage      249
# Mas Vnr Type       11
# Mas Vnr Area       11
# Bsmt Qual          40
# Bsmt Cond          40
# Bsmt Exposure      41
# BsmtFin Type 1     40
# BsmtFin SF 1        1
# BsmtFin Type 2     41
# BsmtFin SF 2        1
# Bsmt Unf SF         1
# Total Bsmt SF       1
# Bsmt Full Bath      1
# Bsmt Half Bath      1
# Garage Type        74
# Garage Yr Blt      75
# Garage Finish      75
# Garage Qual        75
# Garage Cond        75
# dtype: int64
#
#  Lot Frontage      float64
# Mas Vnr Type       object
# Mas Vnr Area      float64
# Bsmt Qual          object
# Bsmt Cond          object
# Bsmt Exposure      object
# BsmtFin Type 1     object
# BsmtFin SF 1      float64
# BsmtFin Type 2     object
# BsmtFin SF 2      float64
# Bsmt Unf SF       float64
# Total Bsmt SF     float64
# Bsmt Full Bath    float64
# Bsmt Half Bath    float64
# Garage Type        object
# Garage Yr Blt     float64
# Garage Finish      object
# Garage Qual        object
# ...

# %%
float_cols = df_missing_values.select_dtypes(include=['float'])
float_cols = float_cols.fillna(float_cols.mean())
print(float_cols.isnull().sum())
# Out:
# Lot Frontage      0
# Mas Vnr Area      0
# BsmtFin SF 1      0
# BsmtFin SF 2      0
# Bsmt Unf SF       0
# Total Bsmt SF     0
# Bsmt Full Bath    0
# Bsmt Half Bath    0
# Garage Yr Blt     0
# dtype: int64
